# %% [markdown]
# <center><h1 style="font-size:2em;color:#2467C0;font-family:Times New Roman">LernKontrolle 21.10.2022</h1></center>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <hr>
#       <h4 style="font-family:courier;font-size:1.3em">
# Lade die CSV Datein 'Dataset.csv' herunter und speichere sie in einem gewünschten Ordner auf deinem Rechner.
# </h4>
# <hr>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#           <h4 style="font-family:courier;font-size:1.7em">
# Aufgabe1
# </h4>
#   <hr>
#       <h4 style="font-family:courier;font-size:1.5em">
# Bearbeite die unteren angegebenen Steps<br>
# </h4>
# </div>

# %% [markdown]
# # Step1
# ### Lese die  'dataset.csv' Datei  und speichere den Dataframe in der Variable 'data'. Gib anschließend die ersten 4 Zeilen des Dataframes aus

# %%
import pandas as pd

data = pd.read_csv("Dataset.csv")
data
# Out:
# C:\Users\hhhme\AppData\Local\Temp\ipykernel_3504\3505001418.py:3: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Dataset.csv")
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# ...

# %% [markdown]
# # Step2
# ## Wie viel NaN hat jeder Spalte!?
# ### Gib anschließend die 10 größten Werte aus

# %%
data.isnull().sum().sort_values(ascending = False).head(10)
# Out:
# Permit Type Definition           198900
# TIDF Compliance                  198898
# Voluntary Soft-Story Retrofit    198865
# Unit Suffix                      196939
# Street Number Suffix             196684
# Site Permit                      193541
# Structural Notification          191978
# Fire Only Permit                 180073
# Unit                             169421
# Completed Date                   101709
# dtype: int64

# %% [markdown]
# # Step 3
# ### Lösche die Spalten wo die Null Werte 50%>

# %%
p = data.isnull().sum()/len(data)
data2 = data[data.columns[p < 0.5]]
data2
# Out:
#         Permit Number  Permit Type Permit Creation Date Block   Lot  \
# 0        2.015051e+11            4           05/06/2015  0326   023
# 1        2.016042e+11            4           04/19/2016  0306   007
# 2        2.016053e+11            3           05/27/2016  0595   203
# 3        2.016111e+11            8           11/07/2016  0156   011
# 4        2.016113e+11            6           11/28/2016  0342   001
# ...               ...          ...                  ...   ...   ...
# 198895            NaN            8           12/05/2017  0113  017A
# 198896   2.017121e+11            8           12/05/2017  0271   014
# 198897            NaN            8           12/06/2017  4318   019
# 198898            NaN            8           12/06/2017  0298   029
# 198899            NaN            8           12/07/2017  0160   006
#
#         Street Number Street Name Street Suffix  \
# 0                 140       Ellis            St
# 1                 440       Geary            St
# ...

# %% [markdown]
# # Step 4
# ### Prozentual gesehen, wie viel NaN Werte gibt es im ganzen DataFrame?

# %%
#oder vielleicht...
data.isna().sum().sum()/(len(data)*data.shape[1])
# Out:
# 0.2902129152197552

# %%
# Out:
# 33.21120574926803

# %% [markdown]
# # step 5
# ### Zeige mithilfe der missingno Library alle NaN Werte in einem Graphen an

# %%
import missingno as msno

msno.matrix(data)
# Out:
# <AxesSubplot: >

# %%
...

# %% [markdown]
# # Step6 (recherche Aufgabe)
# ## Fülle alle NaN Werte in der Spalte "Existing Use" mit dem nächsten darüber liegenden NICHT NaN Wert!
# ## Im zweiten Schritt, füllt die übrigen NaN Werte mit 0.
# ### Die beiden folgenden Tabellen sind Beispiele zur Veranschaulichung. Die erste zeigt die Ausgangstabelle und die zweite das Ergebnis nach Anwendung des zweiten Schrittes.

# %% [markdown]
# Spalte 1 | Spalte 2
# -------- | --------
# NaN   | 1
#  3  | NaN
# NaN | 7
# NaN   | NaN

# %% [markdown]
# ##### Endergebnis
# Spalte 1 | Spalte 2
# -------- | --------
# 0   | 1
#  3  | 1
# 3 | 7
# 3   | 7

# %%
data["Existing Use"].fillna(method='bfill').to_frame()
# Out:
#                Existing Use
# 0       tourist hotel/motel
# 1       tourist hotel/motel
# 2              retail sales
# 3         1 family dwelling
# 4              retail sales
# ...                     ...
# 198895           apartments
# 198896           apartments
# 198897                  NaN
# 198898                  NaN
# 198899                  NaN
#
# [198900 rows x 1 columns]

# %% [markdown]
# # Step 7
# ## Ersetze die NaN Werte in der Spalte "Number of Existing Stories"  mit einer 1

# %%
data["Number of Existing Stories"].fillna("1").to_frame()
# Out:
#        Number of Existing Stories
# 0                             6.0
# 1                             7.0
# 2                             6.0
# 3                             2.0
# 4                             3.0
# ...                           ...
# 198895                          1
# 198896                        4.0
# 198897                          1
# 198898                          1
# 198899                          1
#
# [198900 rows x 1 columns]

# %% [markdown]
# # Step 8
# ## Ersetze die NaN Werte in der Spalte "Existing Units"  mit der Maximale Wert Diese Spalte

# %%
max_ExUn_column = data["Existing Units"].max()
data["Existing Units"].fillna(max_ExUn_column).to_frame()
# Out:
#         Existing Units
# 0                143.0
# 1               1907.0
# 2                 39.0
# 3                  1.0
# 4               1907.0
# ...                ...
# 198895          1907.0
# 198896             4.0
# 198897          1907.0
# 198898          1907.0
# 198899          1907.0
#
# [198900 rows x 1 columns]

# %% [markdown]
# # Step 9
# ## Ersetze die NaN Werte in der Spalte "Plansets"  mit eine Polynomial Interpolation  zweite Ordnung

# %%
b = data["Plansets"].interpolate(method ='linear')
b


data["Plansets"].fillna(b).to_frame()
# Out:
#         Plansets
# 0            2.0
# 1            2.0
# 2            2.0
# 3            2.0
# 4            2.0
# ...          ...
# 198895       1.0
# 198896       2.0
# 198897       2.0
# 198898       2.0
# 198899       2.0
#
# [198900 rows x 1 columns]

# %% [markdown]
# # Step 10
# ### Lade die Aktualisierte Notebook Auf den Server (Github)

# %% [markdown]
# # GOOD LUCK !!!!!
